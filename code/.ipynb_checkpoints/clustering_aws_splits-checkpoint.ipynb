# %%
import ce_functions

# %%
engine = sqlalchemy.create_engine('postgresql://lormanv:vitalystemppw@aurora-stack-auroradbcluster-1rbqp9aty8v4q.cluster-cbs1thv2ku8o.us-east-1.rds.amazonaws.com:5432/recover_p_s6')

# %%
model=Word2Vec.load('./model_all_sites_full')
vocab=list(model.wv.key_to_index.keys())
normed_vectors=model.wv.get_normed_vectors()
normed_vector_df=pd.DataFrame(normed_vectors, index=vocab)
# Out:
# INFO - 14:13:48: loading Word2Vec object from ./model_all_sites_full
# INFO - 14:13:48: loading wv recursively from ./model_all_sites_full.wv.* with mmap=None
# INFO - 14:13:48: loading vectors from ./model_all_sites_full.wv.vectors.npy with mmap=None
# INFO - 14:13:48: loading syn1 from ./model_all_sites_full.syn1.npy with mmap=None
# INFO - 14:13:48: loading syn1neg from ./model_all_sites_full.syn1neg.npy with mmap=None
# INFO - 14:13:48: setting ignored attribute cum_table to None
# INFO - 14:13:49: Word2Vec lifecycle event {'fname': './model_all_sites_full', 'datetime': '2023-03-15T14:13:49.552420', 'gensim': '4.2.0', 'python': '3.7.16 (default, Dec 15 2022, 23:24:54) \n[GCC 7.3.1 20180712 (Red Hat 7.3.1-15)]', 'platform': 'Linux-4.14.304-226.531.amzn2.x86_64-x86_64-with-glibc2.2.5', 'event': 'loaded'}

# %% [markdown]
# ## PEDSnet no labs

# %%
rules_based_cohort_sentences_temp = pd.read_sql_query("SELECT * FROM concept_embeddings.cp_cohort_no_labs_sentences_pedsnet_pasc_78;", engine)
rules_based_sentence_list_temp=rules_based_cohort_sentences_temp.codes.values.tolist()
rules_based_sentences_temp=preloading_sentences(rules_based_sentence_list_temp, model)

lengths=[sent.len() for sent in rules_based_sentences_temp]
not_length_zero=[leng!=0 for leng in lengths]

rules_based_cohort_sentences=rules_based_cohort_sentences_temp[not_length_zero]

rules_based_sentence_list=rules_based_cohort_sentences.codes.values.tolist()
rules_based_sentences=preloading_sentences(rules_based_sentence_list, model)

rules_based_sentence_vecs=sentence_to_vec(sentence_list=rules_based_sentences, embedding_size=200, model=model, a=1000000)
#rules_based_sentence_vecs_alt=sentence_to_vec_alt(sentence_list=rules_based_sentences, embedding_size=200, model=model)



rules_based_normalized_sentence_vecs=[ v / np.linalg.norm(v) for v in rules_based_sentence_vecs[0]]
#rules_based_normalized_sentence_vecs_alt=[ v / np.linalg.norm(v) for v in rules_based_sentence_vecs_alt[0]]

rules_based_sentence_vec_df=pd.DataFrame(rules_based_normalized_sentence_vecs)
#rules_based_sentence_vec_df_alt=pd.DataFrame(rules_based_normalized_sentence_vecs_alt)

rules_based_sentence_vec_df['person_id']=rules_based_cohort_sentences.person_id

# %%
clusterable_embedding = umap.UMAP(
    n_neighbors=20, #0.004*rules_based_sentence_vec_df.shape[0],
    min_dist=0,
    n_components=2,
    random_state=42,
).fit_transform(rules_based_sentence_vec_df.drop(columns=['person_id']))

# %%
labels = hdbscan.HDBSCAN(
    min_samples=5,
    min_cluster_size=(np.floor(rules_based_sentence_vec_df.shape[0]*0.05).astype('int')
)).fit_predict(clusterable_embedding)
print(set(labels))
print(sum(labels==-1))

clustered = (labels >= -1)
plt.scatter(clusterable_embedding[~clustered, 0],
            clusterable_embedding[~clustered, 1],
            color=(0.5, 0.5, 0.5),
            s=0.1,
            alpha=0.5)
plt.scatter(clusterable_embedding[clustered, 0],
            clusterable_embedding[clustered, 1],
            c=labels[clustered],
            s=0.1,
            cmap='Spectral');


print(clusterable_embedding.shape)

embedded_df=pd.DataFrame(clusterable_embedding)

embedded_df['person_id']=rules_based_cohort_sentences.person_id
embedded_df['cluster']=labels

embedded_df.to_sql(name="".join( ["cp_no_labs_embedded_df_pedsnet", "_pasc_88"]), con=engine, if_exists='replace', schema='concept_embeddings')
# Out:
# {0, 1, 2, 3, 4, 5, -1}
# 1011
# (4786, 2)

# %% [markdown]
# ## Non-PEDSnet no lab

# %%
rules_based_cohort_sentences_temp = pd.read_sql_query("SELECT * FROM concept_embeddings.cp_cohort_no_labs_sentences_non_pedsnet_pasc_78;", engine)
rules_based_sentence_list_temp=rules_based_cohort_sentences_temp.codes.values.tolist()
rules_based_sentences_temp=preloading_sentences(rules_based_sentence_list_temp, model)

lengths=[sent.len() for sent in rules_based_sentences_temp]
not_length_zero=[leng!=0 for leng in lengths]

rules_based_cohort_sentences=rules_based_cohort_sentences_temp[not_length_zero]

rules_based_sentence_list=rules_based_cohort_sentences.codes.values.tolist()
rules_based_sentences=preloading_sentences(rules_based_sentence_list, model)

rules_based_sentence_vecs=sentence_to_vec(sentence_list=rules_based_sentences, embedding_size=200, model=model, a=1000000)
#rules_based_sentence_vecs_alt=sentence_to_vec_alt(sentence_list=rules_based_sentences, embedding_size=200, model=model)



rules_based_normalized_sentence_vecs=[ v / np.linalg.norm(v) for v in rules_based_sentence_vecs[0]]
#rules_based_normalized_sentence_vecs_alt=[ v / np.linalg.norm(v) for v in rules_based_sentence_vecs_alt[0]]

rules_based_sentence_vec_df=pd.DataFrame(rules_based_normalized_sentence_vecs)
#rules_based_sentence_vec_df_alt=pd.DataFrame(rules_based_normalized_sentence_vecs_alt)

rules_based_sentence_vec_df['person_id']=rules_based_cohort_sentences.person_id

# %%
clusterable_embedding = umap.UMAP(
    n_neighbors=20, #0.004*rules_based_sentence_vec_df.shape[0],
    min_dist=0,
    n_components=2,
    random_state=42,
).fit_transform(rules_based_sentence_vec_df.drop(columns=['person_id']))

# %%
labels = hdbscan.HDBSCAN(
    min_samples=5,
    min_cluster_size=(np.floor(rules_based_sentence_vec_df.shape[0]*0.05).astype('int')
)).fit_predict(clusterable_embedding)
print(set(labels))
print(sum(labels==-1))



clustered = (labels >= -1)
plt.scatter(clusterable_embedding[~clustered, 0],
            clusterable_embedding[~clustered, 1],
            color=(0.5, 0.5, 0.5),
            s=0.1,
            alpha=0.5)
plt.scatter(clusterable_embedding[clustered, 0],
            clusterable_embedding[clustered, 1],
            c=labels[clustered],
            s=0.1,
            cmap='Spectral');

embedded_df=pd.DataFrame(clusterable_embedding)

print(embedded_df.shape)

embedded_df['person_id']=rules_based_cohort_sentences.person_id
embedded_df['cluster']=labels

embedded_df.to_sql(name="".join( ["cp_no_labs_embedded_df_non_pedsnet", "_pasc_88"]), con=engine, if_exists='replace', schema='concept_embeddings')
# Out:
# {0, 1, 2, 3, 4, 5, -1}
# 1697
# (7370, 2)

# %% [markdown]
# ## PEDSnet COVID positive non-PASC no labs

# %%
rules_based_cohort_sentences_temp = pd.read_sql_query("SELECT * FROM concept_embeddings.cp_pos_no_pasc_cohort_sentences_pasc_78;", engine)
rules_based_sentence_list_temp=rules_based_cohort_sentences_temp.codes.values.tolist()
rules_based_sentences_temp=preloading_sentences(rules_based_sentence_list_temp, model)

lengths=[sent.len() for sent in rules_based_sentences_temp]
not_length_zero=[leng!=0 for leng in lengths]

rules_based_cohort_sentences=rules_based_cohort_sentences_temp[not_length_zero]

rules_based_sentence_list=rules_based_cohort_sentences.codes.values.tolist()
rules_based_sentences=preloading_sentences(rules_based_sentence_list, model)

rules_based_sentence_vecs=sentence_to_vec(sentence_list=rules_based_sentences, embedding_size=200, model=model, a=1000000)
#rules_based_sentence_vecs_alt=sentence_to_vec_alt(sentence_list=rules_based_sentences, embedding_size=200, model=model)



rules_based_normalized_sentence_vecs=[ v / np.linalg.norm(v) for v in rules_based_sentence_vecs[0]]
#rules_based_normalized_sentence_vecs_alt=[ v / np.linalg.norm(v) for v in rules_based_sentence_vecs_alt[0]]

rules_based_sentence_vec_df=pd.DataFrame(rules_based_normalized_sentence_vecs)
#rules_based_sentence_vec_df_alt=pd.DataFrame(rules_based_normalized_sentence_vecs_alt)

rules_based_sentence_vec_df['person_id']=rules_based_cohort_sentences.person_id

# %%
clusterable_embedding = umap.UMAP(
    n_neighbors=20, #0.004*rules_based_sentence_vec_df.shape[0],
    min_dist=0,
    n_components=2,
    random_state=42,
).fit_transform(rules_based_sentence_vec_df.drop(columns=['person_id']))

# %%
clusterable_embedding.shape
# Out:
# (100859, 2)

# %%
labels = hdbscan.HDBSCAN(
    min_samples=5,
    min_cluster_size=(np.floor(rules_based_sentence_vec_df.shape[0]*0.05).astype('int')
)).fit_predict(clusterable_embedding)
print(set(labels))
print(sum(labels==-1))



clustered = (labels >= -1)
plt.scatter(clusterable_embedding[~clustered, 0],
            clusterable_embedding[~clustered, 1],
            color=(0.5, 0.5, 0.5),
            s=0.1,
            alpha=0.5)
plt.scatter(clusterable_embedding[clustered, 0],
            clusterable_embedding[clustered, 1],
            c=labels[clustered],
            s=0.1,
            cmap='Spectral');


print(clusterable_embedding.shape)

embedded_df=pd.DataFrame(clusterable_embedding)

embedded_df['person_id']=rules_based_cohort_sentences.person_id
embedded_df['cluster']=labels

embedded_df.to_sql(name="".join( ["cp_pos_no_pasc_embedded_df", "_pasc_88"]), con=engine, if_exists='replace', schema='concept_embeddings')
# Out:
# {0, 1, -1}
# 31167
# (100859, 2)
